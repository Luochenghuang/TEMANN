# %% [markdown]
# # Tutorial for `temann` module
#
# ---
#
# ## 1. Installing
# 1. `git clone https://github.com/Luochenghuang/TEMANN`
#     - if already cloned, use `git pull` to download the latest version
# 2. `cd TEMANN`
#
# 3. `python setup.py install`
#
# ---
#
# ## 2. Importing `temann`

# %%
import temann

# %% [markdown]
# ---
#
# ## 3. Accessing the data used to train the model
# - TEMDB: ThermoElectric Materials DataBase
# - from DOI: http://dx.doi.org/10.1021/cm400893e

# %%
from temann.data import TEMDB

# %% [markdown]
# #### `TEMDB` is a `pandas.DataFrame` instance and has the same functionality

# %%
TEMDB.head()
# Out:
#     ID    T(K)  Z*10^-4 reported  Resist(Ohm.cm)  Seebeck(uV/K)   kappaZT  \
# 0  1.0   300.0               NaN       50.000000       -462.967  0.000129
# 1  2.0   400.0               NaN       50.000000       -462.967  0.000171
# 2  3.0   700.0               NaN        2.417492       -470.651  0.006414
# 3  4.0  1000.0               NaN        0.177490       -279.829  0.044118
# 4  5.0   300.0               NaN        0.046115       -201.708  0.026468
#
#    Unnamed: 6  Resist(400K)  Seebeck(400K)   Pf(W/K^2/m)     ...       \
# 0         1.0     50.000000       -462.967  4.286770e-07     ...
# 1         1.0     50.000000       -462.967  4.286770e-07     ...
# 2         1.0     50.000000       -462.967  9.162900e-06     ...
# 3         1.0     50.000000       -462.967  4.411760e-05     ...
# 4         1.0      0.046115       -201.708  8.822830e-05     ...
#
#    total_atoms_per_unit_cell  average_atomic_volume ICSD_of_structure  \
# ...

# %%
TEMDB.describe()
# Out:
#                 ID         T(K)  Z*10^-4 reported  Resist(Ohm.cm)  \
# count  1098.000000  1087.000000         63.000000     1098.000000
# mean    549.500000   576.356946        127.571288       22.695998
# std     317.109603   264.474832        295.524366      449.261071
# min       1.000000   300.000000          0.100000        0.000065
# 25%     275.250000   300.000000          0.417075        0.001512
# 50%     549.500000   400.000000          0.730808        0.004872
# 75%     823.750000   700.000000          1.391570        0.022964
# max    1098.000000  1000.000000       1000.000000    14500.000000
#
#        Seebeck(uV/K)       kappaZT   Unnamed: 6  Resist(400K)  Seebeck(400K)  \
# count    1098.000000  1.087000e+03  1093.000000    352.000000     352.000000
# mean      -40.155270  4.116614e-01     4.784995     23.726651     -50.673684
# std       192.691410  7.039567e-01     3.065893    119.162678     178.745718
# ...

# %% [markdown]
# ---
#
# ## 4. Accessing submodules

# %%
from temann import interpret, querry, spacegroup, util

# %% [markdown]
# #### `interpret` submodule

# %%
interpret.get_empirical_formula("Ca0.98La0.02MnO3")
# Out:
# {'Ca': 0.98, 'La': 0.02, 'Mn': 1, 'O': 3}

# %% [markdown]
# #### `spacegroup` submodule

# %%
spacegroup.expand_spacegroup(30)
# Out:
# spacegroup                       30
# crystal system         orthorhombic
# lattice type                      P
# centrosymmetric               False
# symmetry operations               4
# Name: 29, dtype: object

# %% [markdown]
# ---
#
# ## 5. To be continued...
