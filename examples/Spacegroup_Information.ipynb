# %% [markdown]
# ### There are 230 spacegroups. Our data uses the spacegroup number, which has useful information for x-stal system, symmetry elements, ect. When a material is called from the training data and spacegroup info is attached, I want our ANN to have the symmetry information associated with the spacegroup

# %%
import pandas as pd
import numpy as np
import spglib
import ase.spacegroup
from ase.spacegroup import Spacegroup
from temann.MapToInt import *

# %%
# build database of spacegroups, draw key information from spacegroup information
import pandas as pd
import numpy as np
import spglib
import ase.spacegroup
from ase.spacegroup import Spacegroup

# number of spacegroups
num = 230
sg = list(range(1, num+1))
# build empy dataframe
df = pd.DataFrame(data=np.zeros((len(sg), 5)),
                  columns=['spacegroup', 'crystal system', 'lattice type', 'centrosymmetric',
                           'symmetry operations'])

# make column of spacegroup numbers
df['spacegroup'] = sg
# parse crystal system of spacegroups
df['crystal system'] = 'cubic'
df.loc[range(0, 2), 'crystal system'] = 'triclinic'
df.loc[range(2, 15), 'crystal system'] = 'monoclinic'
df.loc[range(15, 74), 'crystal system'] = 'orthorhombic'
df.loc[range(74, 142), 'crystal system'] = 'tetragonal'
df.loc[range(142, 167), 'crystal system'] = 'hexagonal'

# use Spacegroup class to iterate through and populate columns
for i in range(len(df)):
    # populate lattice type from looping through Spacegroup class
    lattice = Spacegroup(i+1).symbol[0]
    df.iloc[i, 2] = lattice
    # whether centrosymmetric for each spacegroup
    centro = Spacegroup(i+1).centrosymmetric
    df.iloc[i, 3] = centro
    # make spacegroup info into list of strings
    strings = str(Spacegroup(i+1))
    # find index for string marking number we want
    idx = strings.find(' symmetry')
    num1 = strings[idx-2]
    num2 = strings[idx-1]
    symmetry = int(num1+num2)
    df.iloc[i, 4] = symmetry
    # DO NOT ADD REST OF HERMANN-MAUGUIN INFORMATION AT THIS TIME, NO GOOD WAY TO USE IT
    # notation = str(Spacegroup(i+1).symbol)
    # notation = notation[2:]
    # df.iloc[i, 5] = notation

# function to input spacegroup and output spacegroup data
def expand_spacegroup(sg):
    """Input a spacegroup number and this function returns various symmetry related descriptors for the material"""
    sg_info = df.loc[sg-1, :]
    return sg_info

# %%
expand_spacegroup(21)
# Out:
# spacegroup                       21
# crystal system         orthorhombic
# lattice type                      C
# centrosymmetric               False
# symmetry operations               4
# Name: 20, dtype: object

# %%
df = pd.DataFrame(data=np.zeros((len(df),6)), columns=['spacegroup', 'crystal system', 'lattice type', 'centrosymmetric', 
                                                      'symmetry operations', 'hermann-mauguin symbol'])
num = 230
# spacegroup identifying number
sg=list(range(1,num+1))
df['spacegroup'] = sg
# parse crystal system of spacegroups
df['crystal system']='cubic'
df.loc[range(0,2),'crystal system'] = 'triclinic'
df.loc[range(2,15),'crystal system'] = 'monoclinic'
df.loc[range(15,74),'crystal system'] = 'orthorhombic'
df.loc[range(74,142),'crystal system'] = 'tetragonal'
df.loc[range(142,167),'crystal system'] = 'hexagonal'

# %%
for i in range(len(df)):
    # populate lattice type from looping through Spacegroup class
    lattice = Spacegroup(i+1).symbol[0]
    df.iloc[i,2] = lattice 
    # whether centrosymmetric for each spacegroup
    centro = Spacegroup(i+1).centrosymmetric
    df.iloc[i,3] = centro
    # make spacegroup info into list of strings
    strings = str(Spacegroup(i+1))
    # find index for string marking number we want
    idx = strings.find(' symmetry')
    num1 = strings[idx-2]
    num2 = strings[idx-1]
    symmetry = int(num1+num2)
    df.iloc[i,4] = symmetry
    # add hermann-mauguin notation
    notation = str(Spacegroup(i+1).symbol)
    notation = notation[2:]
    df.iloc[i,5] = notation
df
# Out:
#      spacegroup crystal system lattice type  centrosymmetric  \
# 0             1      triclinic            P            False
# 1             2      triclinic            P             True
# 2             3     monoclinic            P            False
# 3             4     monoclinic            P            False
# 4             5     monoclinic            C            False
# 5             6     monoclinic            P            False
# 6             7     monoclinic            P            False
# 7             8     monoclinic            C            False
# 8             9     monoclinic            C            False
# 9            10     monoclinic            P             True
# 10           11     monoclinic            P             True
# 11           12     monoclinic            C             True
# 12           13     monoclinic            P             True
# 13           14     monoclinic            P             True
# 14           15     monoclinic            C             True
# 15           16   orthorhombic            P            False
# 16           17   orthorhombic            P            False
# 17           18   orthorhombic            P            False
# 18           19   orthorhombic            P            False
# 19           20   orthorhombic            C            False
# 20           21   orthorhombic            C            False
# 21           22   orthorhombic            F            False
# 22           23   orthorhombic            I            False
# 23           24   orthorhombic            I            False
# 24           25   orthorhombic            P            False
# 25           26   orthorhombic            P            False
# 26           27   orthorhombic            P            False
# 27           28   orthorhombic            P            False
# 28           29   orthorhombic            P            False
# 29           30   orthorhombic            P            False
# ..          ...            ...          ...              ...
# 200         201          cubic            P            False
# 201         202          cubic            F             True
# 202         203          cubic            F            False
# 203         204          cubic            I             True
# 204         205          cubic            P             True
# 205         206          cubic            I             True
# 206         207          cubic            P            False
# 207         208          cubic            P            False
# 208         209          cubic            F            False
# 209         210          cubic            F            False
# 210         211          cubic            I            False
# 211         212          cubic            P            False
# 212         213          cubic            P            False
# 213         214          cubic            I            False
# 214         215          cubic            P            False
# 215         216          cubic            F            False
# 216         217          cubic            I            False
# 217         218          cubic            P            False
# 218         219          cubic            F            False
# 219         220          cubic            I            False
# 220         221          cubic            P             True
# 221         222          cubic            P            False
# 222         223          cubic            P             True
# 223         224          cubic            P            False
# 224         225          cubic            F             True
# 225         226          cubic            F             True
# 226         227          cubic            F            False
# 227         228          cubic            F            False
# 228         229          cubic            I             True
# 229         230          cubic            I             True
#
#      symmetry operations hermann-mauguin symbol
# 0                    1.0                      1
# 1                    1.0                     -1
# 2                    2.0                      2
# 3                    2.0                     21
# 4                    2.0                      2
# 5                    2.0                      m
# 6                    2.0                      c
# 7                    2.0                      m
# 8                    2.0                      c
# 9                    2.0                    2/m
# 10                   2.0                   21/m
# 11                   2.0                    2/m
# 12                   2.0                    2/c
# 13                   2.0                   21/c
# 14                   2.0                    2/c
# 15                   4.0                  2 2 2
# 16                   4.0                 2 2 21
# 17                   4.0                21 21 2
# 18                   4.0               21 21 21
# 19                   4.0                 2 2 21
# 20                   4.0                  2 2 2
# 21                   4.0                  2 2 2
# 22                   4.0                  2 2 2
# 23                   4.0               21 21 21
# 24                   4.0                  m m 2
# 25                   4.0                 m c 21
# 26                   4.0                  c c 2
# 27                   4.0                  m a 2
# 28                   4.0                 c a 21
# 29                   4.0                  n c 2
# ..                   ...                    ...
# 200                 24.0                   n -3
# 201                 12.0                   m -3
# 202                 24.0                   d -3
# 203                 12.0                   m -3
# 204                 12.0                   a -3
# 205                 12.0                   a -3
# 206                 24.0                  4 3 2
# 207                 24.0                 42 3 2
# 208                 24.0                  4 3 2
# 209                 24.0                 41 3 2
# 210                 24.0                  4 3 2
# 211                 24.0                 43 3 2
# 212                 24.0                 41 3 2
# 213                 24.0                 41 3 2
# 214                 24.0                 -4 3 m
# 215                 24.0                 -4 3 m
# 216                 24.0                 -4 3 m
# 217                 24.0                 -4 3 n
# 218                 24.0                 -4 3 c
# 219                 24.0                 -4 3 d
# 220                 24.0                 m -3 m
# 221                 48.0                 n -3 n
# 222                 24.0                 m -3 n
# 223                 48.0                 n -3 m
# 224                 24.0                 m -3 m
# 225                 24.0                 m -3 c
# 226                 48.0                 d -3 m
# 227                 48.0                 d -3 c
# 228                 24.0                 m -3 m
# 229                 24.0                 a -3 d
#
# [230 rows x 6 columns]

# %%
#df.iloc[:,1]
encode_columns(df, 'crystal system')
encode_columns(df, 'lattice type')
df
# Out:
#      spacegroup  crystal system  lattice type  centrosymmetric  \
# 0             1               0             0            False
# 1             2               0             0             True
# 2             3               1             0            False
# 3             4               1             0            False
# 4             5               1             1            False
# 5             6               1             0            False
# 6             7               1             0            False
# 7             8               1             1            False
# 8             9               1             1            False
# 9            10               1             0             True
# 10           11               1             0             True
# 11           12               1             1             True
# 12           13               1             0             True
# 13           14               1             0             True
# 14           15               1             1             True
# 15           16               2             0            False
# 16           17               2             0            False
# 17           18               2             0            False
# 18           19               2             0            False
# 19           20               2             1            False
# 20           21               2             1            False
# 21           22               2             2            False
# 22           23               2             3            False
# 23           24               2             3            False
# 24           25               2             0            False
# 25           26               2             0            False
# 26           27               2             0            False
# 27           28               2             0            False
# 28           29               2             0            False
# 29           30               2             0            False
# ..          ...             ...           ...              ...
# 200         201               5             0            False
# 201         202               5             2             True
# 202         203               5             2            False
# 203         204               5             3             True
# 204         205               5             0             True
# 205         206               5             3             True
# 206         207               5             0            False
# 207         208               5             0            False
# 208         209               5             2            False
# 209         210               5             2            False
# 210         211               5             3            False
# 211         212               5             0            False
# 212         213               5             0            False
# 213         214               5             3            False
# 214         215               5             0            False
# 215         216               5             2            False
# 216         217               5             3            False
# 217         218               5             0            False
# 218         219               5             2            False
# 219         220               5             3            False
# 220         221               5             0             True
# 221         222               5             0            False
# 222         223               5             0             True
# 223         224               5             0            False
# 224         225               5             2             True
# 225         226               5             2             True
# 226         227               5             2            False
# 227         228               5             2            False
# 228         229               5             3             True
# 229         230               5             3             True
#
#      symmetry operations hermann-mauguin symbol
# 0                    1.0                      1
# 1                    1.0                     -1
# 2                    2.0                      2
# 3                    2.0                     21
# 4                    2.0                      2
# 5                    2.0                      m
# 6                    2.0                      c
# 7                    2.0                      m
# 8                    2.0                      c
# 9                    2.0                    2/m
# 10                   2.0                   21/m
# 11                   2.0                    2/m
# 12                   2.0                    2/c
# 13                   2.0                   21/c
# 14                   2.0                    2/c
# 15                   4.0                  2 2 2
# 16                   4.0                 2 2 21
# 17                   4.0                21 21 2
# 18                   4.0               21 21 21
# 19                   4.0                 2 2 21
# 20                   4.0                  2 2 2
# 21                   4.0                  2 2 2
# 22                   4.0                  2 2 2
# 23                   4.0               21 21 21
# 24                   4.0                  m m 2
# 25                   4.0                 m c 21
# 26                   4.0                  c c 2
# 27                   4.0                  m a 2
# 28                   4.0                 c a 21
# 29                   4.0                  n c 2
# ..                   ...                    ...
# 200                 24.0                   n -3
# 201                 12.0                   m -3
# 202                 24.0                   d -3
# 203                 12.0                   m -3
# 204                 12.0                   a -3
# 205                 12.0                   a -3
# 206                 24.0                  4 3 2
# 207                 24.0                 42 3 2
# 208                 24.0                  4 3 2
# 209                 24.0                 41 3 2
# 210                 24.0                  4 3 2
# 211                 24.0                 43 3 2
# 212                 24.0                 41 3 2
# 213                 24.0                 41 3 2
# 214                 24.0                 -4 3 m
# 215                 24.0                 -4 3 m
# 216                 24.0                 -4 3 m
# 217                 24.0                 -4 3 n
# 218                 24.0                 -4 3 c
# 219                 24.0                 -4 3 d
# 220                 24.0                 m -3 m
# 221                 48.0                 n -3 n
# 222                 24.0                 m -3 n
# 223                 48.0                 n -3 m
# 224                 24.0                 m -3 m
# 225                 24.0                 m -3 c
# 226                 48.0                 d -3 m
# 227                 48.0                 d -3 c
# 228                 24.0                 m -3 m
# 229                 24.0                 a -3 d
#
# [230 rows x 6 columns]

# %%
test_expand_spacegroup()
# Out:
# True
